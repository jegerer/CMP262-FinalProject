# %% [markdown]
# ## Name: Jared Egerer
# ## Assignment: Final Project - Milestone #2
# ## Date: 25 April 2023

# %% [markdown]
# **1. Import Libraries and Data Set**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datafile = 'BeerDataSet.csv'
df = pd.read_csv(datafile)

# %%
df
# Out:
#                                              Name  key          Style  \
# 0                                           Amber  251        Altbier
# 1                                      Double Bag  252        Altbier
# 2                                  Long Trail Ale  253        Altbier
# 3                                    Doppelsticke  254        Altbier
# 4                                          Scurry  255        Altbier
# ...                                           ...  ...            ...
# 5553                          Red Nose Winter Ale  696  Winter Warmer
# 5554  Our Special Ale 2019 (Anchor Christmas Ale)  697  Winter Warmer
# 5555                         Fish Tale Winterfish  698  Winter Warmer
# 5556    He'Brew Hanukkah, Chanukah: Pass The Beer  699  Winter Warmer
# 5557     Frosted Frog Christmas Ale - Barrel-Aged  700  Winter Warmer
#
#       Style Key                                  Brewery  \
# 0             8                      Alaskan Brewing Co.
# ...

# %% [markdown]
# **2. Exploratory Data Analysis (EDA)**
# Exploring the data using the following functions and attributes: describe(), columns, shape, dtypes, head(), tail(), sample(), nunique(), and isnull().

# %%
df.describe()
# Out:
#                key    Style Key         ABV   Ave Rating      Min IBU  \
# count  5558.000000  5558.000000  5558.00000  5558.000000  5558.000000
# mean   2779.500000    64.449082     6.63373     3.760239    20.715545
# std    1604.600729    35.814930     2.52166     0.442951    13.736873
# min       1.000000     2.000000     0.00000     1.270000     0.000000
# 25%    1390.250000    34.000000     5.00000     3.590000    10.000000
# 50%    2779.500000    64.000000     6.00000     3.820000    20.000000
# 75%    4168.750000    95.000000     7.90000     4.040000    25.000000
# max    5558.000000   126.000000    57.50000     4.830000    65.000000
#
#            Max IBU  Astringency         Body      Alcohol       Bitter  \
# count  5558.000000  5558.000000  5558.000000  5558.000000  5558.000000
# mean     38.452321    15.938647    42.746132    15.975171    34.316121
# std      22.184524    11.624254    28.589959    18.268342    27.118100
# ...

# %%
df.columns
# Out:
# Index(['Name', 'key', 'Style', 'Style Key', 'Brewery', 'Description', 'ABV',
#        'Ave Rating', 'Min IBU', 'Max IBU', 'Astringency', 'Body', 'Alcohol',
#        'Bitter', 'Sweet', 'Sour', 'Salty', 'Fruits', 'Hoppy', 'Spices',
#        'Malty'],
#       dtype='object')

# %%
df.shape
# Out:
# (5558, 21)

# %%
df.dtypes
# Out:
# Name            object
# key              int64
# Style           object
# Style Key        int64
# Brewery         object
# Description     object
# ABV            float64
# Ave Rating     float64
# Min IBU          int64
# Max IBU          int64
# Astringency      int64
# Body             int64
# Alcohol          int64
# Bitter           int64
# Sweet            int64
# Sour             int64
# Salty            int64
# Fruits           int64
# Hoppy            int64
# Spices           int64
# Malty            int64
# dtype: object

# %%
df.head()
# Out:
#              Name  key    Style  Style Key                         Brewery  \
# 0           Amber  251  Altbier          8             Alaskan Brewing Co.
# 1      Double Bag  252  Altbier          8          Long Trail Brewing Co.
# 2  Long Trail Ale  253  Altbier          8          Long Trail Brewing Co.
# 3    Doppelsticke  254  Altbier          8  Uerige Obergärige Hausbrauerei
# 4          Scurry  255  Altbier          8               Off Color Brewing
#
#                                          Description  ABV  Ave Rating  \
# 0  Notes:Richly malty and long on the palate, wit...  5.3        3.65
# 1  Notes:This malty, full-bodied double alt is al...  7.2        3.90
# 2  Notes:Long Trail Ale is a full-bodied amber al...  5.0        3.58
# 3                                             Notes:  8.5        4.15
# 4  Notes:Just cause it's dark and German doesn't ...  5.3        3.67
#
#    Min IBU  Max IBU  ...  Body  Alcohol  Bitter  Sweet  Sour  Salty  Fruits  \
# ...

# %%
df.tail()
# Out:
#                                              Name  key          Style  \
# 5553                          Red Nose Winter Ale  696  Winter Warmer
# 5554  Our Special Ale 2019 (Anchor Christmas Ale)  697  Winter Warmer
# 5555                         Fish Tale Winterfish  698  Winter Warmer
# 5556    He'Brew Hanukkah, Chanukah: Pass The Beer  699  Winter Warmer
# 5557     Frosted Frog Christmas Ale - Barrel-Aged  700  Winter Warmer
#
#       Style Key                                  Brewery  \
# 5553         17         Natty Greene's Pub & Brewing Co.
# 5554         17                   Anchor Brewing Company
# 5555         17  Fish Brewing Company / Fishbowl Brewpub
# 5556         17                  Shmaltz Brewing Company
# 5557         17                     Hoppin' Frog Brewery
#
#                                             Description  ABV  Ave Rating  \
# 5553                                             Notes:  6.8        3.59
# ...

# %%
df.sample(10)
# Out:
#                                         Name   key  \
# 5199                      Summer Session Ale  4891
# 3192                                Invasion  2030
# 1108                          Biere De Norma  1809
# 5295  Trader Joe's Bavarian Style Hefeweizen  4987
# 3186                    New DogTown Pale Ale  2024
# 885                     Buster Nut Brown Ale   436
# 5524                                   4 Elf   667
# 3247                     Saranac Belgian Ale  2085
# 1676                          India Pale Ale  1477
# 4838                    Chocolate Milk Stout  4180
#
#                                Style  Style Key  \
# 5199      Wheat Beer - American Pale        111
# 3192             Pale Ale - American         48
# 1108  Farmhouse Ale - Bière de Garde         44
# 5295         Wheat Beer - Hefeweizen        113
# 3186             Pale Ale - American         48
# 885              Brown Ale - English         11
# 5524                   Winter Warmer         17
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5558 entries, 0 to 5557
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5556 non-null   object
#  1   key          5558 non-null   int64
#  2   Style        5558 non-null   object
#  3   Style Key    5558 non-null   int64
#  4   Brewery      5558 non-null   object
#  5   Description  5558 non-null   object
#  6   ABV          5558 non-null   float64
#  7   Ave Rating   5558 non-null   float64
#  8   Min IBU      5558 non-null   int64
#  9   Max IBU      5558 non-null   int64
#  10  Astringency  5558 non-null   int64
#  11  Body         5558 non-null   int64
#  12  Alcohol      5558 non-null   int64
#  13  Bitter       5558 non-null   int64
#  14  Sweet        5558 non-null   int64
#  15  Sour         5558 non-null   int64
#  16  Salty        5558 non-null   int64
#  17  Fruits       5558 non-null   int64
# ...

# %%
df = df.rename(columns = {
    'Name' : 'name', 
    'key' : 'key', 
    'Style' : 'style', 
    'Style Key' : 'style_key', 
    'Brewery' : 'brewery', 
    'Description' : 'desc', 
    'ABV' : 'abv', 
    'Ave Rating' : 'avg_rating', 
    'Min IBU' : 'ibu_min', 
    'Max IBU' : 'ibu_max', 
    'Astringency' : 'text_astringency', 
    'Body' : 'text_body', 
    'Alcohol' : 'text_alcohol', 
    'Bitter' : 'text_bitter', 
    'Sweet' : 'text_sweet', 
    'Sour' : 'text_sour', 
    'Salty' : 'text_salty', 
    'Fruits' : 'text_fruits', 
    'Hoppy' : 'text_hoppy', 
    'Spices' : 'text_spices', 
    'Malty' : 'text_malty'
})

# %%
df['ibu_avg'] = (df['ibu_min'] + df['ibu_max']) / 2
df = df[['name', 'style', 'brewery', 'desc', 'abv', 'avg_rating', 'ibu_min', 'ibu_max', 'ibu_avg', 'text_astringency', 'text_body', 'text_alcohol', 'text_bitter',
        'text_sweet', 'text_sour', 'text_salty', 'text_fruits', 'text_hoppy', 'text_spices', 'text_malty']]
df
# Out:
#                                              name          style  \
# 0                                           Amber        Altbier
# 1                                      Double Bag        Altbier
# 2                                  Long Trail Ale        Altbier
# 3                                    Doppelsticke        Altbier
# 4                                          Scurry        Altbier
# ...                                           ...            ...
# 5553                          Red Nose Winter Ale  Winter Warmer
# 5554  Our Special Ale 2019 (Anchor Christmas Ale)  Winter Warmer
# 5555                         Fish Tale Winterfish  Winter Warmer
# 5556    He'Brew Hanukkah, Chanukah: Pass The Beer  Winter Warmer
# 5557     Frosted Frog Christmas Ale - Barrel-Aged  Winter Warmer
#
#                                       brewery  \
# 0                         Alaskan Brewing Co.
# 1                      Long Trail Brewing Co.
# ...

# %%
df.nunique()
# Out:
# name                5317
# style                112
# brewery             1498
# desc                3347
# abv                  229
# avg_rating           289
# ibu_min               21
# ibu_max               25
# ibu_avg               35
# text_astringency      73
# text_body            165
# text_alcohol         116
# text_bitter          141
# text_sweet           191
# text_sour            222
# text_salty            47
# text_fruits          185
# text_hoppy           156
# text_spices          155
# text_malty           217
# dtype: int64

# %%
set(df['style'])
# Out:
# {'Altbier',
#  'Barleywine - American',
#  'Barleywine - English',
#  'Bitter - English',
#  'Bitter - English Extra Special / Strong Bitter (ESB)',
#  'Bière de Champagne / Bière Brut',
#  'Blonde Ale - American',
#  'Blonde Ale - Belgian',
#  'Bock - Doppelbock',
#  'Bock - Eisbock',
#  'Bock - Maibock',
#  'Bock - Traditional',
#  'Bock - Weizenbock',
#  'Braggot',
#  'Brett Beer',
#  'Brown Ale - American',
#  'Brown Ale - Belgian Dark',
#  'Brown Ale - English',
#  'California Common / Steam Beer',
#  'Chile Beer',
#  'Cream Ale',
#  'Dubbel',
#  'Farmhouse Ale - Bière de Garde',
#  'Farmhouse Ale - Sahti',
#  'Farmhouse Ale - Saison',
#  'Fruit and Field Beer',
#  'Gruit / Ancient Herbed Ale',
#  'Happoshu',
#  'Herb and Spice Beer',
#  'IPA - American',
#  'IPA - Belgian',
#  'IPA - Black / Cascadian Dark Ale',
#  'IPA - Brut',
#  'IPA - English',
#  'IPA - Imperial',
#  'IPA - New England',
#  'Kvass',
#  'Kölsch',
#  'Lager - Adjunct',
#  'Lager - American',
# ...

# %%
df.isnull().sum()
# Out:
# name                2
# style               0
# brewery             0
# desc                0
# abv                 0
# avg_rating          0
# ibu_min             0
# ibu_max             0
# ibu_avg             0
# text_astringency    0
# text_body           0
# text_alcohol        0
# text_bitter         0
# text_sweet          0
# text_sour           0
# text_salty          0
# text_fruits         0
# text_hoppy          0
# text_spices         0
# text_malty          0
# dtype: int64

# %%
df_styles = df[['style', 'ibu_avg']].drop_duplicates().reset_index()
df_styles = df_styles[['style', 'ibu_avg']]
df_styles
# Out:
#                                                  style  ibu_avg
# 0                                              Altbier     37.5
# 1                                Barleywine - American     80.0
# 2                                 Barleywine - English     50.0
# 3    Bitter - English Extra Special / Strong Bitter...     30.0
# 4                                     Bitter - English     27.5
# ..                                                 ...      ...
# 107                        Wheat Beer - Kristallweizen     12.5
# 108                             Wheat Beer - Wheatwine     65.0
# 109                               Wheat Beer - Witbier     15.0
# 110                                           Wild Ale     17.5
# 111                                      Winter Warmer     42.5
#
# [112 rows x 2 columns]

# %% [markdown]
# **3. Data cleaning**
# Using isnull(), identify the observations with NaN values.  Then, replace those values with the correct values using loc().

# %%
df[df['name'].isnull()]
# Out:
#      name                  style            brewery    desc  abv  avg_rating  \
# 1803  NaN                  Kvass  Monastyrskiy Kvas  Notes:  1.5        3.07
# 2150  NaN  Lager - European Pale      Stella Artois  Notes:  5.0        3.11
#
#       ibu_min  ibu_max  ibu_avg  text_astringency  text_body  text_alcohol  \
# 1803        0        0      0.0                 8         34             4
# 2150       18       25     21.5                 8         14            10
#
#       text_bitter  text_sweet  text_sour  text_salty  text_fruits  text_hoppy  \
# 1803           15          84         16           1           33          14
# 2150           20          19          3           0            1          26
#
#       text_spices  text_malty
# 1803            7          68
# 2150            3          26

# %%
df.loc[2150, 'name'] = 'Stella Artois'
df.loc[1803, 'name'] = 'Monastyrskiy Kvas'
df[df['name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [name, style, brewery, desc, abv, avg_rating, ibu_min, ibu_max, ibu_avg, text_astringency, text_body, text_alcohol, text_bitter, text_sweet, text_sour, text_salty, text_fruits, text_hoppy, text_spices, text_malty]
# Index: []

# %%
df.loc[1803]
# Out:
# name                Monastyrskiy Kvas
# style                           Kvass
# brewery             Monastyrskiy Kvas
# desc                           Notes:
# abv                               1.5
# avg_rating                       3.07
# ibu_min                             0
# ibu_max                             0
# ibu_avg                           0.0
# text_astringency                    8
# text_body                          34
# text_alcohol                        4
# text_bitter                        15
# text_sweet                         84
# text_sour                          16
# text_salty                          1
# text_fruits                        33
# text_hoppy                         14
# text_spices                         7
# text_malty                         68
# Name: 1803, dtype: object

# %%
df.loc[2150]
# Out:
# name                        Stella Artois
# style               Lager - European Pale
# brewery                     Stella Artois
# desc                               Notes:
# abv                                   5.0
# avg_rating                           3.11
# ibu_min                                18
# ibu_max                                25
# ibu_avg                              21.5
# text_astringency                        8
# text_body                              14
# text_alcohol                           10
# text_bitter                            20
# text_sweet                             19
# text_sour                               3
# text_salty                              0
# text_fruits                             1
# text_hoppy                             26
# text_spices                             3
# text_malty                             26
# Name: 2150, dtype: object

# %% [markdown]
# Investigate alcohol % by volume (ABV) greater than 15.  Most beer has an ABV no greater than 13%, but in EDA, the range for ABV went to 57.5%.  Beers with an ABV value of 0 also existed in this data set.  What are they?

# %%
df[df['abv'] > 15]
# Out:
#                                                    name  \
# 63                                A Deal With The Devil
# 137                                   Bommen & Granaten
# 451                                   Raspberry Eisbock
# 458                                     Double Ice Bock
# 464                                    Schorschbock 31%
# 474                                    Schorschbock 57%
# 483                                  Four Years Dessert
# 494                                   My Name Is Legion
# 496                                   Medusalem Eisbock
# 685               Ghost Bees - Apple Brandy Barrel-Aged
# 1273                                               Fort
# 1705                                     120 Minute IPA
# 3774                                            Rumpkin
# 4091                                   Ryeway To Heaven
# 4472                                   World Wide Stout
# 4479                                      Black Tuesday
# ...

# %%
df[df['abv'] == 0]
# Out:
#                                                    name  \
# 839                    Black Jack (Bourbon Barrel Aged)
# 845               North By Northwest Okanogan Black Ale
# 1986                               Hudepohl Amber Lager
# 1999                                         Mojave Red
# 2777  Wild Hop Organic Amber LagerGreen Valley Brewi...
# 3052                                            Saunter
# 3073                                    Lake Lightening
# 3107                                        Spring Mild
# 3110                                     Jacob Mac Mild
# 3753                           Stagecoach Smoked Porter
# 5127                                        Ruddy Wheat
# 5133                                       Winter Wheat
# 5149                               Whitman's Wheat Beer
# 5158                                       Robust Wheat
# 5255                         Steingadener Weisse Dunkel
# 5329                           Franconia Kristal-weizen
# ...

# %% [markdown]
# These beers may be worth investigating since they do not appear to be non-alcoholic.

# %% [markdown]
# **Question 1: Based on average ratings for breweries, which breweries perform the best and the worst overall?**

# %% [markdown]
# Before conducting this analysis, we should consider trimming down the breweries that have only a small handful of different products.  To this end, an arbitrary threshold of five is chosen.

# %%
breweries_more_than_5 = df.groupby('brewery').filter(lambda x : x['brewery'].size >= 5)

# %%
breweries_more_than_5.groupby('brewery')['name'].count().sort_values(ascending = False)
# Out:
# brewery
# Boston Beer Company (Samuel Adams)    81
# Anheuser-Busch                        49
# Dogfish Head Craft Brewery            41
# 3 Floyds Brewing Co.                  40
# Short's Brewing Company               36
#                                       ..
# Suntory                                5
# Franconia Brewing Company              5
# Pyramid Breweries, Inc.                5
# Swinkels Family Brewers                5
# Iron Hill Brewery & Restaurant         5
# Name: name, Length: 309, dtype: int64

# %% [markdown]
# By choosing this threshold, the number of remaining breweries has been reduced from 1,498 to 309.

# %%
brew_more_5_sorted = breweries_more_than_5.groupby('brewery').aggregate({'brewery': 'count', 'avg_rating': 'mean'}).sort_values(by = 'avg_rating', ascending = False)
brew_more_5_sorted
# Out:
#                                   brewery  avg_rating
# brewery
# Side Project Brewing                    6    4.515000
# Tree House Brewing Company             29    4.445517
# Trillium Brewing Company               21    4.425714
# Fremont Brewing Company                 8    4.378750
# Hill Farmstead Brewery                 32    4.363437
# ...                                   ...         ...
# JOS. Schlitz Brewing Co. (Pabst)        5    2.724000
# Brauerei Beck & Co.                     9    2.705556
# Pabst Brewing Company                  18    2.649444
# Anheuser-Busch                         49    2.451224
# Miller Brewing Co.                     19    2.099474
#
# [309 rows x 2 columns]

# %%
breweries_more_than_5
# Out:
#                                              name          style  \
# 0                                           Amber        Altbier
# 1                                      Double Bag        Altbier
# 2                                  Long Trail Ale        Altbier
# 4                                          Scurry        Altbier
# 5                    Sleigh'r Dark Doüble Alt Ale        Altbier
# ...                                           ...            ...
# 5551                                   Winter Ale  Winter Warmer
# 5552                           The First Snow Ale  Winter Warmer
# 5554  Our Special Ale 2019 (Anchor Christmas Ale)  Winter Warmer
# 5556    He'Brew Hanukkah, Chanukah: Pass The Beer  Winter Warmer
# 5557     Frosted Frog Christmas Ale - Barrel-Aged  Winter Warmer
#
#                          brewery  \
# 0            Alaskan Brewing Co.
# 1         Long Trail Brewing Co.
# 2         Long Trail Brewing Co.
# 4              Off Color Brewing
# ...

# %%
brew_more_5_sorted.rename(columns = {
    'brewery': 'count',
    'avg_rating': 'rating'
}, inplace = True)

# %%
brew_more_5_sorted
# Out:
#                                   count    rating
# brewery
# Side Project Brewing                  6  4.515000
# Tree House Brewing Company           29  4.445517
# Trillium Brewing Company             21  4.425714
# Fremont Brewing Company               8  4.378750
# Hill Farmstead Brewery               32  4.363437
# ...                                 ...       ...
# JOS. Schlitz Brewing Co. (Pabst)      5  2.724000
# Brauerei Beck & Co.                   9  2.705556
# Pabst Brewing Company                18  2.649444
# Anheuser-Busch                       49  2.451224
# Miller Brewing Co.                   19  2.099474
#
# [309 rows x 2 columns]

# %%
brew_more_5_sorted.reset_index(inplace = True)
brew_more_5_sorted
# Out:
#                               brewery  count    rating
# 0                Side Project Brewing      6  4.515000
# 1          Tree House Brewing Company     29  4.445517
# 2            Trillium Brewing Company     21  4.425714
# 3             Fremont Brewing Company      8  4.378750
# 4              Hill Farmstead Brewery     32  4.363437
# ..                                ...    ...       ...
# 304  JOS. Schlitz Brewing Co. (Pabst)      5  2.724000
# 305               Brauerei Beck & Co.      9  2.705556
# 306             Pabst Brewing Company     18  2.649444
# 307                    Anheuser-Busch     49  2.451224
# 308                Miller Brewing Co.     19  2.099474
#
# [309 rows x 3 columns]

# %%
top_5 = breweries_more_than_5[breweries_more_than_5.brewery.isin(brew_more_5_sorted['brewery'].head())].reset_index().drop('index', axis = 1)
top_5
# Out:
#                        name  \
# 0               Day & Night
# 1                     Aaron
# 2                   Old Man
# 3           Blanc De Blancs
# 4           Eureka W/ Citra
# ..                      ...
# 91           Coconut B-Bomb
# 92  Pier American Wheat Ale
# 93        Maple in the Wood
# 94                    Fuzzy
# 95               Winter Ale
#
#                                                 style  \
# 0                               Barleywine - American
# 1                                Barleywine - English
# 2   Bitter - English Extra Special / Strong Bitter...
# 3                     Bière de Champagne / Bière Brut
# 4                               Blonde Ale - American
# ..                                                ...
# 91                              Strong Ale - American
# 92                         Wheat Beer - American Pale
# 93                             Wheat Beer - Wheatwine
# 94                                           Wild Ale
# ...

# %%
bottom_5 = breweries_more_than_5[breweries_more_than_5.brewery.isin(brew_more_5_sorted['brewery'].tail())].reset_index().drop('index', axis = 1)
bottom_5
# Out:
#                                name                       style  \
# 0                Ballantine XXX Ale       Blonde Ale - American
# 1                Michelob AmberBock          Bock - Traditional
# 2                  Redd's Apple Ale        Fruit and Field Beer
# 3            Shock Top Lemon Shandy        Fruit and Field Beer
# 4               Best Damn Root Beer         Herb and Spice Beer
# ..                              ...                         ...
# 95  Shock Top Twisted Pretzel Wheat  Wheat Beer - American Dark
# 96        Shock Top Chocolate Wheat  Wheat Beer - American Dark
# 97              Shock Top Wheat IPA  Wheat Beer - American Pale
# 98           Michelob Dunkel Weisse   Wheat Beer - Dunkelweizen
# 99          Shock Top Belgian White        Wheat Beer - Witbier
#
#                   brewery                                               desc  \
# 0   Pabst Brewing Company                                             Notes:
# ...

# %%
top_5_stats = top_5.groupby(['brewery', 'style']).aggregate({'brewery': 'count', 'avg_rating': 'mean'})
top_5_stats.rename(columns = {
    'brewery': 'count',
    'avg_rating': 'rating'
}, inplace = True)
top_5_stats.sort_values(by = ['brewery', 'count'], ascending = (1, 0), inplace = True)
top_5_stats.reset_index(inplace = True)
top_5_stats
# Out:
#                        brewery  \
# 0      Fremont Brewing Company
# 1      Fremont Brewing Company
# 2      Fremont Brewing Company
# 3       Hill Farmstead Brewery
# 4       Hill Farmstead Brewery
# 5       Hill Farmstead Brewery
# 6       Hill Farmstead Brewery
# 7       Hill Farmstead Brewery
# 8       Hill Farmstead Brewery
# 9       Hill Farmstead Brewery
# 10      Hill Farmstead Brewery
# 11      Hill Farmstead Brewery
# 12      Hill Farmstead Brewery
# 13      Hill Farmstead Brewery
# 14      Hill Farmstead Brewery
# 15      Hill Farmstead Brewery
# 16      Hill Farmstead Brewery
# 17      Hill Farmstead Brewery
# 18      Hill Farmstead Brewery
# 19        Side Project Brewing
# 20        Side Project Brewing
# 21        Side Project Brewing
# 22        Side Project Brewing
# 23        Side Project Brewing
# 24        Side Project Brewing
# 25  Tree House Brewing Company
# 26  Tree House Brewing Company
# 27  Tree House Brewing Company
# 28  Tree House Brewing Company
# ...

# %%
bottom_5_stats = bottom_5.groupby(['brewery', 'style']).aggregate({'brewery': 'count', 'avg_rating': 'mean'})
bottom_5_stats.rename(columns = {
    'brewery': 'count',
    'avg_rating': 'rating'
}, inplace = True)
bottom_5_stats.sort_values(by = ['brewery', 'count'], ascending = (1, 0), inplace = True)
bottom_5_stats.reset_index(inplace = True)
bottom_5_stats
# Out:
#                              brewery                         style  count  \
# 0                     Anheuser-Busch                 Lager - Light     14
# 1                     Anheuser-Busch           Lager - Malt Liquor     12
# 2                     Anheuser-Busch  Lager - American Amber / Red      5
# 3                     Anheuser-Busch               Lager - Adjunct      4
# 4                     Anheuser-Busch              Low Alcohol Beer      4
# 5                     Anheuser-Busch    Wheat Beer - American Dark      2
# 6                     Anheuser-Busch            Bock - Traditional      1
# 7                     Anheuser-Busch          Fruit and Field Beer      1
# 8                     Anheuser-Busch           Herb and Spice Beer      1
# 9                     Anheuser-Busch              Lager - American      1
# 10                    Anheuser-Busch           Lager - Schwarzbier      1
# 11                    Anheuser-Busch    Wheat Beer - American Pale      1
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize = (24, 10))

for ax, (name, sub_df) in zip(axs.ravel(), top_5_stats.groupby('brewery')):
    labels = sub_df['rating']
    ax.barh(sub_df['style'], sub_df['count'])
    ax.set_title(name)
    ax.set_xticks(range(0, 14, 1))

fig.delaxes(axs[1][2])
fig.tight_layout()

# %%
fig, axs = plt.subplots(2, 3, figsize = (24, 10))

for ax, (name, sub_df) in zip(axs.ravel(), bottom_5_stats.groupby('brewery')):
    ax.barh(sub_df['style'], sub_df['count'])
    ax.set_title(name)
    ax.set_xticks(range(0, 14, 1))

fig.delaxes(axs[1][2])
fig.tight_layout()

# %% [markdown]
# **Question 2: Based on the text analysis, what are the two or three most frequently associated words for the top 10 (by rating) styles of beer?**

# %%
style_more_than_20 = df.groupby('style').filter(lambda x : x['style'].size >= 20)
style_more_than_20
# Out:
#                                              name          style  \
# 0                                           Amber        Altbier
# 1                                      Double Bag        Altbier
# 2                                  Long Trail Ale        Altbier
# 3                                    Doppelsticke        Altbier
# 4                                          Scurry        Altbier
# ...                                           ...            ...
# 5553                          Red Nose Winter Ale  Winter Warmer
# 5554  Our Special Ale 2019 (Anchor Christmas Ale)  Winter Warmer
# 5555                         Fish Tale Winterfish  Winter Warmer
# 5556    He'Brew Hanukkah, Chanukah: Pass The Beer  Winter Warmer
# 5557     Frosted Frog Christmas Ale - Barrel-Aged  Winter Warmer
#
#                                       brewery  \
# 0                         Alaskan Brewing Co.
# 1                      Long Trail Brewing Co.
# ...

# %%
top_10_styles = style_more_than_20.groupby('style').aggregate({'avg_rating': 'mean'}).sort_values(by = 'avg_rating', ascending = False).head(10)
top_10_styles.reset_index(inplace = True)
top_10_styles
# Out:
#                        style  avg_rating
# 0          IPA - New England    4.505000
# 1  Stout - American Imperial    4.367800
# 2                   Wild Ale    4.305510
# 3             IPA - Imperial    4.272000
# 4   Stout - Russian Imperial    4.233200
# 5          Porter - Imperial    4.178600
# 6           Quadrupel (Quad)    4.150800
# 7       Barleywine - English    4.121000
# 8             Lambic - Fruit    4.110408
# 9     Farmhouse Ale - Saison    4.090600

# %%
top_10 = style_more_than_20[style_more_than_20['style'].isin(top_10_styles['style'])].reset_index().drop('index', axis = 1)
top_10
# Out:
#                                                   name                 style  \
# 0                  Bourbon County Brand Barleywine Ale  Barleywine - English
# 1                                               §ucaba  Barleywine - English
# 2                                             Insanity  Barleywine - English
# 3                                     Blithering Idiot  Barleywine - English
# 4                                 Mother Of All Storms  Barleywine - English
# ..                                                 ...                   ...
# 493  Samuel Adams Stony Brook Red (Barrel Room Coll...              Wild Ale
# 494                                      Aurelian Lure              Wild Ale
# 495                                         Funk Metal              Wild Ale
# 496                          Cascade Vlad The Imp Aler              Wild Ale
# 497                             Farmer's Reserve Pluot              Wild Ale
#
# ...

# %%
top_10_agg = top_10.groupby('style').aggregate({
    'text_astringency': 'sum',
    'text_body': 'sum',
    'text_alcohol': 'sum',
    'text_bitter': 'sum',
    'text_sweet': 'sum',
    'text_sour': 'sum',
    'text_salty': 'sum',
    'text_fruits': 'sum',
    'text_hoppy': 'sum',
    'text_spices': 'sum',
    'text_malty': 'sum'
})
top_10_agg.reset_index(inplace = True)
top_10_agg.rename(columns = ({
    'style': 'beer_style',
    'text_astringency': 'astringency',
    'text_body': 'body',
    'text_alcohol': 'alcohol',
    'text_bitter': 'bitter',
    'text_sweet': 'sweet',
    'text_sour': 'sour',
    'text_salty': 'salty',
    'text_fruits': 'fruits',
    'text_hoppy': 'hoppy',
    'text_spices': 'spices',
    'text_malty': 'malty'}), inplace = True)
top_10_agg
# Out:
#                   beer_style  astringency  body  alcohol  bitter  sweet  sour  \
# 0       Barleywine - English          455  2981     2848    1585   6033  1490
# 1     Farmhouse Ale - Saison         1538  1698      667    1309   2565  5230
# 2             IPA - Imperial          808  1845     1111    3471   2703  2726
# 3          IPA - New England         1174  2335      579    3204   3459  4048
# 4             Lambic - Fruit         1670  1498      401     222   4087  6433
# 5          Porter - Imperial          418  4873     1781    3193   4048   550
# 6           Quadrupel (Quad)          512  2873     3091    1011   6143  1884
# 7  Stout - American Imperial          405  4753     2236    3070   3555   409
# 8   Stout - Russian Imperial          416  4938     1843    3083   3862   691
# 9                   Wild Ale         1858  1597      705     489   3837  7725
#
#    salty  fruits  hoppy  spices  malty
# 0     20    3181   1405    1206   5839
# ...

# %%
top_10_melt = top_10_agg.melt(id_vars = 'beer_style', 
                          value_vars = ['astringency', 'body', 'alcohol', 'bitter', 'sweet', 
                                        'sour', 'salty', 'fruits', 'hoppy', 'spices', 'malty'],
                          var_name = 'attrib', value_name = 'count') 
top_10_sort = top_10_melt.sort_values(by = ['beer_style', 'count'], ascending = (1, 0))
top_10_attrib = top_10_sort.groupby('beer_style').head(3).reset_index().drop('index', axis = 1)
top_10_attrib
# Out:
#                    beer_style  attrib  count
# 0        Barleywine - English   sweet   6033
# 1        Barleywine - English   malty   5839
# 2        Barleywine - English  fruits   3181
# 3      Farmhouse Ale - Saison    sour   5230
# 4      Farmhouse Ale - Saison  fruits   4338
# 5      Farmhouse Ale - Saison   sweet   2565
# 6              IPA - Imperial   hoppy   4766
# 7              IPA - Imperial  fruits   3869
# 8              IPA - Imperial  bitter   3471
# 9           IPA - New England  fruits   7276
# 10          IPA - New England    sour   4048
# 11          IPA - New England   hoppy   3915
# 12             Lambic - Fruit    sour   6433
# 13             Lambic - Fruit  fruits   5241
# 14             Lambic - Fruit   sweet   4087
# 15          Porter - Imperial   malty   7239
# 16          Porter - Imperial    body   4873
# 17          Porter - Imperial   sweet   4048
# 18           Quadrupel (Quad)   sweet   6143
# 19           Quadrupel (Quad)  fruits   4131
# ...

# %%
fig, axs = plt.subplots(2, 5, figsize = (24, 10))

for ax, (name, sub_df) in zip(axs.ravel(), top_10_attrib.groupby('beer_style')):
    ax.pie(sub_df['count'], labels = sub_df['attrib'], autopct='%.2f%%')
    ax.set_title(name)

fig.tight_layout()
